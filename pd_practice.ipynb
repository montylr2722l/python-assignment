# %%
#Dataframe

import pandas as pd
student = {
    "name" : ["Alice", "Bob", "Charlie"],
    "age" : [20, 21, 22],
    "city" :["New york", "Los Angeles", "Chicago"]
}

df = pd.DataFrame(student)
print(df)
print(df.shape)
print(df[df.columns[2]])
# Out:
#       name  age         city
# 0    Alice   20     New york
# 1      Bob   21  Los Angeles
# 2  Charlie   22      Chicago
# (3, 3)
# 0       New york
# 1    Los Angeles
# 2        Chicago
# Name: city, dtype: str
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 14
#      10 df = pd.DataFrame(student)
#      11 print(df)
#      12 print(df.shape)
#      13 print(df[df.columns[2]])
# ---> 14 print(df[df.index])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
# ...
