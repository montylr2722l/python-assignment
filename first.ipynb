# %%
n1 = int(input("Enter a number: "))
print(type(n1))
# Out:
# hello world
# <class 'int'>

# %%
a = "hello"
b = "python"
print(a +" "+ b)
print(a.center(20,"*"))
# Out:
# hello python
# *******hello********

# %%
a = "this is PythonFinalizationError"
b = "hello"
print(a.isalpha()) #check whether the string is alphabetic or not. It returns false because of space and capital letter
print(a.isalnum()) #check whether the string is alphanumeric or not
print(a.isdigit()) #check whether the string is digit or not
print(a.replace("PythonFinalizationError", "COPLUR")) #it will replace the word PythonFinalizationError with COPLUR
# Out:
# False
# False
# False
# this is COPLUR

# %%
string = ("hello", "sir")
print(" ".join(string)) # it will join the elements of the tuple and return a string    
l = "rtpon"
e = "12345"
encoding = a.maketrans(l,e) # it will create a translation table for the characters in l and e
print(a.translate(encoding)) # it will translate the characters in a using the translation table created    
p = "this is python"
q = "this"
if q in p:
    print("yes")
else:
 print("no")
# Out:
# hello sir
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 5
#       1 string = ("hello", "sir")
#       2 print(" ".join(string)) # it will join the elements of the tuple and return a string
#       3 l = "rtpon"
#       4 e = "12345"
# ----> 5 encoding = a.maketrans(l,e) # it will create a translation table for the characters in l and e
#       6 print(a.translate(encoding)) # it will translate the characters in a using the translation table created
#       7 p = "this is python"
#       8 q = "this"
#
# AttributeError: 'int' object has no attribute 'maketrans'

# %%
n = 15

if (n >= 0 and n <= 10):
    print("number is between 0 and 10")

elif (n > 10 and n <= 20):
    print("number is between 10 and 20")

elif (n > 15):
    print("number is greater than 15")

else:
    print("number is smaller than 20")
# Out:
# number is between 10 and 20

# %%
a = 10
b = 20 
c = 30
if (a > b and a > c):
    print("a is the greatest number")
elif (b > a and b > c):
    print("b is the greatest number")
else:
    print("c is the greatest number")
# Out:
# c is the greatest number

# %%
n1 = int(input("enter a number:"))
operator = input("enter an operator: ")
n2 = int(input("enter another number: "))
if operator == "+":
    print(n1 + n2)
elif operator == "-":
    print(n1 - n2)  
elif operator == "*":
    print(n1 * n2)  
elif operator == "/":
    print(n1 / n2) 
elif    operator == "%":
    print(n1 % n2)
else:
    print("invalid operator")
# Out:
# invalid operator

# %%
k = input("enter a no.: ")
for i in range(1, 11):
    print(f"{k} x {i} = {int(k) * i}")
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
text = "programming"
print(text[::-1]) # it will print the string in reverse order   
print(text[0:4]) # it will print the characters from shlex import joinfrom index 0 to 3
count = 0
for i in text:
        count += 1
print(count)
# Out:
# gnimmargorp
# prog
# 11
